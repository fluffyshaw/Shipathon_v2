# %%
import pandas as pd

data = pd.read_csv('train.csv',usecols=["Genre","Lyrics"])

# %%
print(data.head(1))
# Out:
#   Genre                                             Lyrics
# 0  Rock  It starts with pain, followed by hate\nFueled ...
